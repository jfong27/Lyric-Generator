# %% [markdown]
# ## Analysis
#
# Compare the quality of the lyrics generated by the unigram model (in Part 2) and the bigram model (in Part 3). Which model seems to generate more reasonable lyrics? Can you explain why? What do you see as the advantages and disadvantages of each model?

# %% [markdown]
# The bigram model seems to generate more reasonable and coherent lyrics, but they are also more similar to the actual lines that the artist wrote. Some of the lines created by the bigram model are identical to lines in his songs. The unigram model creates lyrics that do not make as much sense, but they are more unique.
#
# The reason the bigram model generates lyrics that make more sense is because there is less variability of next possible words. If there are many unique words, you end up with lyrics that are very similar to the original source material.
#
# The unigram model has a higher level of variability, so it has a higher chance of the next word not making sense in the context of the whole line. The model creates much more unique songs compared to the bigram model, but has a higher chance of creating nonsensical lyrics.

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 10 points.]

# %%
# This cell should only be modified only by a grader.
scores = [None]
